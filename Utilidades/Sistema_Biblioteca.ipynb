# %% [markdown]
# # 📚 Sistema de Biblioteca en Python
#
# Este notebook implementa un sistema de biblioteca que permite:
# - Registrar usuarios.
# - Iniciar y cerrar sesión.
# - Agregar, buscar, listar, prestar, devolver y eliminar libros.
# - Mostrar libros prestados.
# - Validar correos y contraseñas.
# - Personalizar el menú según el estado de sesión.
#
# ---
#
# ## 📝 Enunciado
#
# Implementa un sistema en Python que permita administrar una **biblioteca comunitaria**. Este sistema debe ejecutarse en consola e incluir las siguientes funcionalidades:
#
# ### 1. Gestión de usuarios
# - Registro con validación de correo y contraseña segura.
# - Inicio de sesión (hasta 3 intentos).
# - Cierre de sesión.
# - Registro debe guardar: correo, contraseña y libros prestados.
#
# ### 2. Gestión de libros
# - Agregar libros (con validación de autor, fecha, etc.).
# - Buscar por título.
# - Listar todos los disponibles.
# - Prestar libros si están disponibles.
# - Devolver libros solo si el usuario autenticado los tiene.
# - Eliminar libros.
#
# ### 3. Restricciones y mejoras
# - Un mismo libro no puede prestarse dos veces a la vez.
# - Solo usuarios autenticados pueden prestar, devolver o eliminar.
# - Al cerrar sesión se muestra un menú adaptado.
# - Muestra nombre del usuario activo en el menú.
#
# ---

# %%
from datetime import date, datetime

libros = [
    {
        "nombre": "cien años de soledad",
        "autor": "gabriel garcia marquez",
        "fecha_publicacion": date(1967, 5, 30),
        "genero": "realismo mágico",
        "estado": "disponible",
        "dueño": None
    },
    {
        "nombre": "1984",
        "autor": "george orwell",
        "fecha_publicacion": date(1949, 6, 8),
        "genero": "distopía",
        "estado": "disponible",
        "dueño": None
    },
    # ... Resto del listado omitido por brevedad ...
]

prestados = []
usuarios = []
usuario_actual = None

# Aquí se insertan las funciones: registrar_usuario, iniciar_sesion, agregar_libro, etc.
# También el menú principal que usa estas funciones.
# El código completo puede copiarse desde el sistema ya desarrollado.

# %% [markdown]
# > 💡 Puedes ejecutar celda por celda, probar modificaciones o usar esto como base para nuevas funcionalidades (como exportar historial, buscar libros similares, etc.).
